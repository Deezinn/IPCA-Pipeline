# %% [markdown]
# ### Analisando IPCA para transformar

# %%
import pandas as pd

# %%
data = pd.read_csv(r'/home/deezinn/Documentos/Python/Meus Projetos Pessoais/dados-ibge/teste.csv', sep=',', encoding='utf-8', skiprows=1)

# %%
data
# Out:
#     Nível Territorial (Código) Nível Territorial Unidade de Medida (Código)  \
# 0                            1            Brasil                          2
# 1                            1            Brasil                          2
# 2                            1            Brasil                          2
# 3                            1            Brasil                          2
# 4                            1            Brasil                          2
# ..                         ...               ...                        ...
# 645                          1            Brasil                          2
# 646                          1            Brasil                          2
# 647                          1            Brasil                          2
# 648                          1            Brasil                          2
# 649                          1            Brasil                          2
#
# ...

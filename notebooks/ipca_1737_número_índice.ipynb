# %% [markdown]
# ### Analisando IPCA para transformar

# %%
import pandas as pd

# %%
data = pd.read_csv(r'../data/Tabela 1737 - IPCA número-índice.csv', sep=',', encoding='utf-8', skiprows=1)

# %%
data
# Out:
#      Nível Territorial (Código) Nível Territorial  Unidade de Medida (Código)  \
# 0                             1            Brasil                          30
# 1                             1            Brasil                          30
# 2                             1            Brasil                          30
# 3                             1            Brasil                          30
# 4                             1            Brasil                          30
# ..                          ...               ...                         ...
# 536                           1            Brasil                          30
# 537                           1            Brasil                          30
# 538                           1            Brasil                          30
# 539                           1            Brasil                          30
# 540                           1            Brasil                          30
#
# ...

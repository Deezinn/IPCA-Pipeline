# %% [markdown]
# ### Analisando IPCA para transformar

# %%
import pandas as pd

# %%
data = pd.read_csv(r'../data/Tabela 1737 - IPCA variação mensal.csv', sep=',', encoding='utf-8', skiprows=1)

# %%
data
# Out:
#      Nível Territorial (Código) Nível Territorial  Unidade de Medida (Código)  \
# 0                             1            Brasil                         NaN
# 1                             1            Brasil                         2.0
# 2                             1            Brasil                         2.0
# 3                             1            Brasil                         2.0
# 4                             1            Brasil                         2.0
# ..                          ...               ...                         ...
# 536                           1            Brasil                         2.0
# 537                           1            Brasil                         2.0
# 538                           1            Brasil                         2.0
# 539                           1            Brasil                         2.0
# 540                           1            Brasil                         2.0
#
# ...

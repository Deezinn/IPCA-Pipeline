# %% [markdown]
# ### Analisando IPCA para transformar

# %%
import pandas as pd

# %%
data = pd.read_csv(r'../data/Tabela 118 - IPCA dessazonalizado.csv', sep=',', encoding='utf-8', skiprows=1)

# %%
data
# Out:
#      Nível Territorial (Código) Nível Territorial  Unidade de Medida (Código)  \
# 0                             1            Brasil                           2
# 1                             1            Brasil                           2
# 2                             1            Brasil                           2
# 3                             1            Brasil                           2
# 4                             1            Brasil                           2
# ..                          ...               ...                         ...
# 319                           1            Brasil                           2
# 320                           1            Brasil                           2
# 321                           1            Brasil                           2
# 322                           1            Brasil                           2
# 323                           1            Brasil                           2
#
# ...
